# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'D:\\PythonWorkspace\\gitrepo\\data_by_rank.csv', sep=',')
df.head(10)
# Out:
#          matchId     gameVersion       rank  \
# 0  KR_5266752731  11.12.379.4946  DIAMOND-I
# 1  KR_5275521774  11.12.379.4946  DIAMOND-I
# 2  KR_5275532435  11.12.379.4946  DIAMOND-I
# 3  KR_5282894572  11.13.382.1241  DIAMOND-I
# 4  KR_5282963488  11.13.382.1241  DIAMOND-I
# 5  KR_5282964924  11.13.382.1241  DIAMOND-I
# 6  KR_5289447024  11.13.382.1241  DIAMOND-I
# 7  KR_5291224245  11.13.382.1241  DIAMOND-I
# 8  KR_5291403254  11.13.382.1241  DIAMOND-I
# 9  KR_5291453093  11.13.382.1241  DIAMOND-I
#
#                                           playerData  \
# 0  [{'assists': 3, 'baronKills': 0, 'bountyLevel'...
# 1  [{'assists': 4, 'baronKills': 0, 'bountyLevel'...
# 2  [{'assists': 2, 'baronKills': 0, 'bountyLevel'...
# 3  [{'assists': 3, 'baronKills': 0, 'bountyLevel'...
# 4  [{'assists': 11, 'baronKills': 0, 'bountyLevel...
# 5  [{'assists': 9, 'baronKills': 0, 'bountyLevel'...
# 6  [{'assists': 5, 'baronKills': 0, 'bountyLevel'...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37848 entries, 0 to 37847
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   matchId      37848 non-null  object
#  1   gameVersion  37848 non-null  object
#  2   rank         37848 non-null  object
#  3   playerData   37848 non-null  object
#  4   teamsData    37848 non-null  object
# dtypes: object(5)
# memory usage: 1.4+ MB
