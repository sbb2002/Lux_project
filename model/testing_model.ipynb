# %%
import glob, pickle
import pandas as pd
from package import *

pkls = glob.glob(r'D:\PythonWorkspace\gitrepo\Lux_project\model\*.pkl')

Lux_all_all_v1 = pkls[0]
Lux_all_all_v2 = pkls[1]
Lux_all_silvers_v1 = pkls[2]
Lux_all_silvers_v2 = pkls[3]
Lux_mid_all_v1 = pkls[4]
Lux_mid_all_v2 = pkls[5]
Lux_mid_silvers_v1 = pkls[6]
Lux_mid_silvers_v2 = pkls[7]

# %% [markdown]
# # Test in real set

# %% [markdown]
# ## v1. only my data

# %%
xy = data_preprocessing.dataset_for_me_v1("Lux")

x = xy.iloc[:, 2:-1]
y = xy.iloc[:, [-1]]

# %%
with open(Lux_all_all_v1, 'rb') as f:
    lrg_all_all_v1 = pickle.load(f)

data_preprocessing.right_counter(lrg_all_all_v1, x, y)
# Out:
# Right: 16/19
#       win  prediction          proba  right
# 0   False       False   2.769075e-47   True
# 1   False       False   4.245666e-58   True
# 2   False       False  1.299329e-116   True
# 3   False       False  2.075113e-107   True
# 4   False       False   2.231275e-48   True
# 5    True       False  3.681928e-139  False
# 6   False       False   5.208558e-79   True
# 7   False       False  4.951601e-104   True
# 8    True       False  2.239768e-143  False
# 9   False       False   2.707937e-56   True
# 10  False       False  2.186568e-203   True
# 11  False       False  6.267937e-132   True
# 12  False       False  3.756870e-222   True
# 13  False       False  1.070638e-133   True
# 14  False       False   5.368397e-82   True
# 15  False       False  2.884484e-244   True
# 16   True        True   9.975750e-01   True
# 17   True       False  2.015578e-121  False
# 18  False       False   4.189170e-82   True

# %%
with open(Lux_all_silvers_v1, 'rb') as f:
    Lux_all_silvers_v1 = pickle.load(f)

data_preprocessing.right_counter(Lux_all_silvers_v1, x, y)
# Out:
# Right: 16/19
#       win  prediction         proba  right
# 0   False       False  1.981193e-16   True
# 1   False       False  6.395409e-19   True
# 2   False       False  1.183950e-30   True
# 3   False       False  1.434750e-53   True
# 4   False       False  1.866158e-21   True
# 5    True       False  1.586404e-29  False
# 6   False       False  4.116182e-34   True
# 7   False       False  4.553222e-43   True
# 8    True       False  6.842376e-36  False
# 9   False       False  5.929963e-24   True
# 10  False       False  1.390863e-74   True
# 11  False       False  3.414330e-49   True
# 12  False       False  1.212692e-78   True
# 13  False       False  2.979714e-52   True
# 14  False       False  5.332926e-29   True
# 15  False       False  1.844266e-85   True
# 16   True        True  1.000000e+00   True
# 17   True       False  2.286030e-25  False
# 18  False       False  3.240552e-38   True

# %%
with open(Lux_mid_all_v1, 'rb') as f:
    Lux_mid_all_v1 = pickle.load(f)

data_preprocessing.right_counter(Lux_mid_all_v1, x, y)
# Out:
# Right: 15/19
#       win  prediction          proba  right
# 0   False       False   1.912123e-55   True
# 1   False       False   3.070218e-67   True
# 2   False       False  2.949740e-143   True
# 3   False       False   4.354865e-87   True
# 4   False       False   5.775898e-46   True
# 5    True       False  5.837733e-183  False
# 6   False       False   6.348540e-81   True
# 7   False       False  5.476318e-112   True
# 8    True       False  4.502333e-191  False
# 9   False       False   7.832382e-58   True
# 10  False       False  6.581515e-248   True
# 11  False       False  1.589155e-161   True
# 12  False       False  1.502070e-269   True
# 13  False       False  3.160661e-155   True
# 14  False       False   1.680138e-87   True
# 15  False       False  8.105063e-299   True
# 16   True       False   2.045320e-02  False
# 17   True       False  1.208384e-170  False
# 18  False       False   2.558866e-68   True

# %%
with open(Lux_mid_silvers_v1, 'rb') as f:
    Lux_mid_silvers_v1 = pickle.load(f)

data_preprocessing.right_counter(Lux_mid_silvers_v1, x, y)
# Out:
# Right: 16/19
#       win  prediction         proba  right
# 0   False       False  3.958462e-15   True
# 1   False       False  1.960962e-17   True
# 2   False       False  7.460353e-31   True
# 3   False       False  6.167377e-31   True
# 4   False       False  1.143899e-14   True
# 5    True       False  1.879710e-35  False
# 6   False       False  4.530493e-25   True
# 7   False       False  1.131756e-34   True
# 8    True       False  1.695688e-43  False
# 9   False       False  1.323036e-17   True
# 10  False       False  2.630224e-71   True
# 11  False       False  2.110513e-47   True
# 12  False       False  7.560886e-75   True
# 13  False       False  3.556456e-46   True
# 14  False       False  2.237829e-22   True
# 15  False       False  1.024474e-82   True
# 16   True        True  1.000000e+00   True
# 17   True       False  1.261297e-36  False
# 18  False       False  4.994863e-23   True

# %% [markdown]
# ## v2. total kd

# %%
xy = data_preprocessing.dataset_for_me_v2("Lux")

x = xy.iloc[:, 2:-1]
y = xy.iloc[:, [-1]]

# %%
with open(Lux_all_all_v2, 'rb') as f:
    Lux_all_all_v2 = pickle.load(f)

data_preprocessing.right_counter(Lux_all_all_v2, x, y)
# Out:
# Right: 16/19
#       win  prediction          proba  right
# 0   False       False  1.962154e-126   True
# 1   False       False  4.616854e-195   True
# 2   False       False  3.591326e-214   True
# 3   False       False  1.989772e-265   True
# 4   False       False  7.917809e-164   True
# 5    True       False   3.126452e-73  False
# 6   False       False  1.113235e-146   True
# 7   False       False  3.337871e-177   True
# 8    True       False   5.257762e-74  False
# 9   False       False  2.867451e-123   True
# 10  False       False  5.495717e-209   True
# 11  False       False  1.551726e-173   True
# 12  False       False  9.801897e-234   True
# 13  False       False  4.982512e-168   True
# 14  False       False  1.310856e-177   True
# 15  False       False  5.280199e-270   True
# 16   True        True   1.000000e+00   True
# 17   True       False   1.388520e-12  False
# 18  False       False  7.072348e-254   True

# %%
with open(Lux_mid_all_v2, 'rb') as f:
    Lux_mid_all_v2 = pickle.load(f)

data_preprocessing.right_counter(Lux_mid_all_v2, x, y)
# Out:
# Right: 16/19
#       win  prediction          proba  right
# 0   False       False   1.185150e-91   True
# 1   False       False  2.591669e-132   True
# 2   False       False  8.921517e-180   True
# 3   False       False  2.811421e-172   True
# 4   False       False  2.502226e-105   True
# 5    True       False  3.545929e-127  False
# 6   False       False  1.740757e-110   True
# 7   False       False  2.789694e-140   True
# 8    True       False  1.443343e-130  False
# 9   False       False   1.495287e-89   True
# 10  False       False  3.632096e-220   True
# 11  False       False  1.307852e-162   True
# 12  False       False  5.001238e-243   True
# 13  False       False  1.675377e-155   True
# 14  False       False  2.023886e-132   True
# 15  False       False  6.705843e-276   True
# 16   True        True   7.361677e-01   True
# 17   True       False   7.880337e-91  False
# 18  False       False  1.095150e-159   True

# %%
with open(Lux_all_silvers_v2, 'rb') as f:
    Lux_all_silvers_v2 = pickle.load(f)

data_preprocessing.right_counter(Lux_all_silvers_v2, x, y)
# Out:
# Right: 17/19
#       win  prediction          proba  right
# 0   False       False   7.900589e-70   True
# 1   False       False  1.014158e-107   True
# 2   False       False  9.352434e-108   True
# 3   False       False  4.806818e-160   True
# 4   False       False   3.198171e-96   True
# 5    True       False   2.671085e-15  False
# 6   False       False   1.423921e-82   True
# 7   False       False   3.933200e-97   True
# 8    True       False   3.857297e-17  False
# 9   False       False   1.051146e-70   True
# 10  False       False  9.520714e-100   True
# 11  False       False   4.513575e-87   True
# 12  False       False  1.428098e-110   True
# 13  False       False   4.949827e-86   True
# 14  False       False   3.239932e-98   True
# 15  False       False  8.494029e-129   True
# 16   True        True   1.000000e+00   True
# 17   True        True   1.000000e+00   True
# 18  False       False  2.677273e-150   True

# %%
with open(Lux_mid_silvers_v2, 'rb') as f:
    Lux_mid_silvers_v2 = pickle.load(f)

data_preprocessing.right_counter(Lux_mid_silvers_v2, x, y)
# Out:
# Right: 16/19
#       win  prediction         proba  right
# 0   False       False  2.255797e-37   True
# 1   False       False  4.778532e-57   True
# 2   False       False  6.592241e-60   True
# 3   False       False  2.650977e-79   True
# 4   False       False  2.264393e-48   True
# 5    True       False  2.912290e-21  False
# 6   False       False  1.325841e-46   True
# 7   False       False  4.281055e-58   True
# 8    True       False  1.268538e-28  False
# 9   False       False  4.856829e-38   True
# 10  False       False  3.232836e-78   True
# 11  False       False  6.032394e-62   True
# 12  False       False  6.496409e-84   True
# 13  False       False  1.123477e-59   True
# 14  False       False  5.031959e-51   True
# 15  False       False  4.204368e-96   True
# 16   True        True  1.000000e+00   True
# 17   True       False  3.581287e-10  False
# 18  False       False  1.983594e-74   True

# %%
Lux_all_silvers_v2.coef_
# Out:
# array([[ 0.75053184, -2.45780569,  0.81114758, -0.4249818 ,  0.62298311,
#          1.91373828,  0.355218  ,  5.24232619,  2.8929931 , -7.3714584 ]])
